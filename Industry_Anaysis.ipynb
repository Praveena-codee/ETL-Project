# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#Store INDUSTRY CSV into DataFrame
csv_file = "Resources/industry_employment.csv"
industry_data_df = pd.read_csv(csv_file)
industry_data_df.head()
# Out:
#   Annual industry employment movements, 2016-17 to 2018-19      Unnamed: 1  \
# 0                                                NaN        2016-17 ('000)
# 1                  Agriculture, forestry and fishing                    -9
# 2                                             Mining                    -7
# 3                                      Manufacturing                    -7
# 4         Electricity, gas, water and waste services                     1
#
#        Unnamed: 2      Unnamed: 3
# 0  2017-18 ('000)  2018-19 ('000)
# 1             -14              -8
# 2              12              10
# 3              10              14
# 4               3               5

# %%
##  Rename the column headers
industry_data_df = industry_data_df.rename(columns={"Annual industry employment movements, 2016-17 to 2018-19": "industry",
                                                          "Unnamed: 1": "emp_2017",
                                                          "Unnamed: 2": "emp_2018",
                                                          "Unnamed: 3": "emp_2019"})
industry_data_df = industry_data_df.rename(columns={"Industry": "industry"})
## Clean the data
industry_clean_df=industry_data_df.dropna(how='any')
industry_clean_df.head()
# Out:
#                                      industry emp_2017 emp_2018 emp_2019
# 1           Agriculture, forestry and fishing       -9      -14       -8
# 2                                      Mining       -7       12       10
# 3                               Manufacturing       -7       10       14
# 4  Electricity, gas, water and waste services        1        3        5
# 5                                Construction       14       47        4

# %%
# dropping duplicates and setting the index
#industry_data_df.drop_duplicates("Industry", inplace=True)
industry_clean_df.set_index("industry", inplace=True)

industry_clean_df.head()
# Out:
#                                            emp_2017 emp_2018 emp_2019
# industry
# Agriculture, forestry and fishing                -9      -14       -8
# Mining                                           -7       12       10
# Manufacturing                                    -7       10       14
# Electricity, gas, water and waste services        1        3        5
# Construction                                     14       47        4

# %%
#Store EMPLOYMENT CSV into DataFrame
csv_file = "Resources/Industry_EBITDA.csv"
earnings_data_df = pd.read_csv(csv_file)
earnings_data_df.head()
# Out:
#   Annual industry EBITDA movements, 2016-17 to 2018-19    Unnamed: 1  \
# 0                                                NaN    2016-17 ($m)
# 1                  Agriculture, forestry and fishing           3,694
# 2                                             Mining          23,313
# 3                                      Manufacturing          -1,064
# 4         Electricity, gas, water and waste services           3,254
#
#      Unnamed: 2    Unnamed: 3
# 0  2017-18 ($m)  2018-19 ($m)
# 1        -2,258          -998
# 2        21,399        33,746
# 3         4,201         3,346
# 4           481           670

# %%
##  Rename the column headers
earnings_data_df = earnings_data_df.rename(columns={"Annual industry EBITDA movements, 2016-17 to 2018-19": "Industry",
                                                         "Unnamed: 1": "earnings_2017",
                                                          "Unnamed: 2": "earnings_2018",
                                                          "Unnamed: 3": "earnings_2019"})
earnings_data_df = earnings_data_df.rename(columns={"Industry": "industry"})
## Clean the data
earnings_clean_df= earnings_data_df.dropna(how='any')
earnings_clean_df.set_index("industry", inplace=True)
earnings_clean_df.head()
# Out:
#                                            earnings_2017 earnings_2018  \
# industry
# Agriculture, forestry and fishing                  3,694        -2,258
# Mining                                            23,313        21,399
# Manufacturing                                     -1,064         4,201
# Electricity, gas, water and waste services         3,254           481
# Construction                                         435         3,404
#
#                                            earnings_2019
# industry
# Agriculture, forestry and fishing                   -998
# Mining                                            33,746
# Manufacturing                                      3,346
# Electricity, gas, water and waste services           670
# Construction                                       2,504

# %%
#removing the "," from data
earnings_clean_df.earnings_2017 = earnings_clean_df.earnings_2017.str.replace(',', '')

earnings_clean_df.head()


#earnings_clean_df["y_2017"] = pd.to_numeric(earnings_clean_df["y_2017"])
# Out:
# C:\Users\Praveena\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                            earnings_2017 earnings_2018  \
# industry
# Agriculture, forestry and fishing                   3694        -2,258
# Mining                                             23313        21,399
# Manufacturing                                      -1064         4,201
# Electricity, gas, water and waste services          3254           481
# Construction                                         435         3,404
#
#                                            earnings_2019
# industry
# Agriculture, forestry and fishing                   -998
# Mining                                            33,746
# Manufacturing                                      3,346
# Electricity, gas, water and waste services           670
# Construction                                       2,504

# %%
earnings_clean_df.earnings_2018 = earnings_clean_df.earnings_2018.str.replace(',', '')

earnings_clean_df.head()
# Out:
# C:\Users\Praveena\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                            earnings_2017 earnings_2018  \
# industry
# Agriculture, forestry and fishing                   3694         -2258
# Mining                                             23313         21399
# Manufacturing                                      -1064          4201
# Electricity, gas, water and waste services          3254           481
# Construction                                         435          3404
#
#                                            earnings_2019
# industry
# Agriculture, forestry and fishing                   -998
# Mining                                            33,746
# Manufacturing                                      3,346
# Electricity, gas, water and waste services           670
# Construction                                       2,504

# %%
earnings_clean_df.earnings_2019 = earnings_clean_df.earnings_2019.str.replace(',', '')
earnings_clean_df.head()
# Out:
# C:\Users\Praveena\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                            earnings_2017 earnings_2018  \
# industry
# Agriculture, forestry and fishing                   3694         -2258
# Mining                                             23313         21399
# Manufacturing                                      -1064          4201
# Electricity, gas, water and waste services          3254           481
# Construction                                         435          3404
#
#                                            earnings_2019
# industry
# Agriculture, forestry and fishing                   -998
# Mining                                             33746
# Manufacturing                                       3346
# Electricity, gas, water and waste services           670
# Construction                                        2504

# %%
earnings_clean_df = earnings_clean_df.loc[:, ["earnings_2017", "earnings_2018", "earnings_2019"]]
earnings_clean_df
# Out:
#                                                 earnings_2017 earnings_2018  \
# industry
# Agriculture, forestry and fishing                        3694         -2258
# Mining                                                  23313         21399
# Manufacturing                                           -1064          4201
# Electricity, gas, water and waste services               3254           481
# Construction                                              435          3404
# Wholesale trade                                          -310          3197
# Retail trade                                              873           516
# Accommodation and food services                          -972            23
# Transport, postal and warehousing                        1191           612
# Information media and telecommunications                 -776            -7
# Rental, hiring and real estate services                  3587          -212
# Professional, scientific and technical services          2485          1419
# Administrative and support services                      1237          -189
# Public administration and safety (private)                133           220
# Education and training (private)                         -302           101
# Health care and social assistance (private)              1142          2155
# Arts and recreation services                              218           556
# Other services                                           -119          -482
#
#                                                 earnings_2019
# industry
# Agriculture, forestry and fishing                        -998
# Mining                                                  33746
# Manufacturing                                            3346
# Electricity, gas, water and waste services                670
# Construction                                             2504
# Wholesale trade                                          1099
# Retail trade                                             -325
# Accommodation and food services                           132
# Transport, postal and warehousing                        1371
# Information media and telecommunications                -2050
# Rental, hiring and real estate services                   157
# Professional, scientific and technical services          2238
# Administrative and support services                       109
# Public administration and safety (private)                 30
# Education and training (private)                          374
# Health care and social assistance (private)              1870
# Arts and recreation services                              339
# Other services                                            862

# %%
earnings_clean_df = earnings_clean_df.loc[:, ["earnings_2017", "earnings_2018", "earnings_2019"]].astype(int)
earnings_clean_df
# Out:
#                                                  earnings_2017  earnings_2018  \
# industry
# Agriculture, forestry and fishing                         3694          -2258
# Mining                                                   23313          21399
# Manufacturing                                            -1064           4201
# Electricity, gas, water and waste services                3254            481
# Construction                                               435           3404
# Wholesale trade                                           -310           3197
# Retail trade                                               873            516
# Accommodation and food services                           -972             23
# Transport, postal and warehousing                         1191            612
# Information media and telecommunications                  -776             -7
# Rental, hiring and real estate services                   3587           -212
# Professional, scientific and technical services           2485           1419
# Administrative and support services                       1237           -189
# Public administration and safety (private)                 133            220
# Education and training (private)                          -302            101
# Health care and social assistance (private)               1142           2155
# Arts and recreation services                               218            556
# Other services                                            -119           -482
#
#                                                  earnings_2019
# industry
# Agriculture, forestry and fishing                         -998
# Mining                                                   33746
# Manufacturing                                             3346
# Electricity, gas, water and waste services                 670
# Construction                                              2504
# Wholesale trade                                           1099
# Retail trade                                              -325
# Accommodation and food services                            132
# Transport, postal and warehousing                         1371
# Information media and telecommunications                 -2050
# Rental, hiring and real estate services                    157
# Professional, scientific and technical services           2238
# Administrative and support services                        109
# Public administration and safety (private)                  30
# Education and training (private)                           374
# Health care and social assistance (private)               1870
# Arts and recreation services                               339
# Other services                                             862

# %%
# sorting the data in ascending order
sort_by_high_earnings = earnings_clean_df.sort_values(["earnings_2017", "earnings_2018", "earnings_2019"], ascending = False)
sort_by_high_earnings
# Out:
#                                                  earnings_2017  earnings_2018  \
# industry
# Mining                                                   23313          21399
# Agriculture, forestry and fishing                         3694          -2258
# Rental, hiring and real estate services                   3587           -212
# Electricity, gas, water and waste services                3254            481
# Professional, scientific and technical services           2485           1419
# Administrative and support services                       1237           -189
# Transport, postal and warehousing                         1191            612
# Health care and social assistance (private)               1142           2155
# Retail trade                                               873            516
# Construction                                               435           3404
# Arts and recreation services                               218            556
# Public administration and safety (private)                 133            220
# Other services                                            -119           -482
# Education and training (private)                          -302            101
# Wholesale trade                                           -310           3197
# Information media and telecommunications                  -776             -7
# Accommodation and food services                           -972             23
# Manufacturing                                            -1064           4201
#
#                                                  earnings_2019
# industry
# Mining                                                   33746
# Agriculture, forestry and fishing                         -998
# Rental, hiring and real estate services                    157
# Electricity, gas, water and waste services                 670
# Professional, scientific and technical services           2238
# Administrative and support services                        109
# Transport, postal and warehousing                         1371
# Health care and social assistance (private)               1870
# Retail trade                                              -325
# Construction                                              2504
# Arts and recreation services                               339
# Public administration and safety (private)                  30
# Other services                                             862
# Education and training (private)                           374
# Wholesale trade                                           1099
# Information media and telecommunications                 -2050
# Accommodation and food services                            132
# Manufacturing                                             3346

# %%
pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\praveena\anaconda3\lib\site-packages (2.8.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
#  create database connection
connection_string = "postgres:Prav123@localhost:5432/Industry_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['industry', 'earnings']

# %%
industry_clean_df.to_sql(name='industry', con=engine, if_exists='replace', index=True)

# %%
earnings_clean_df.to_sql(name='earnings', con=engine, if_exists='replace', index=True)

# %%
#Confirm data has been added by querying 
pd.read_sql_query('select * from industry', con=engine)
# Out:
#                                            industry  emp_2017  emp_2018  \
# 0                 Agriculture, forestry and fishing        -9       -14
# 1                                            Mining        -7        12
# 2                                     Manufacturing        -7        10
# 3        Electricity, gas, water and waste services         1         3
# 4                                      Construction        14        47
# 5                                   Wholesale trade        15        -3
# 6                                      Retail trade       -16        27
# 7                   Accommodation and food services        34        20
# 8                 Transport, postal and warehousing         8        15
# 9          Information media and telecommunications        -3         1
# 10          Rental, hiring and real estate services         2        13
# 11  Professional, scientific and technical services        55        61
# 12              Administrative and support services        42        64
# 13       Public administration and safety (private)         1         0
# 14                 Education and training (private)         7        14
# 15      Health care and social assistance (private)        30        66
# 16                     Arts and recreation services        -1         8
# 17                                   Other services        -3        17
#
#     emp_2019
# 0         -8
# 1         10
# 2         14
# 3          5
# 4          4
# 5         17
# 6         21
# 7          2
# 8         20
# 9         -1
# 10        -3
# 11        56
# 12        29
# 13         4
# 14        16
# 15       109
# 16        16
# 17        14

# %%
pd.read_sql_query('select * from earnings', con=engine)
# Out:
#                                            industry  earnings_2017  \
# 0                 Agriculture, forestry and fishing           3694
# 1                                            Mining          23313
# 2                                     Manufacturing          -1064
# 3        Electricity, gas, water and waste services           3254
# 4                                      Construction            435
# 5                                   Wholesale trade           -310
# 6                                      Retail trade            873
# 7                   Accommodation and food services           -972
# 8                 Transport, postal and warehousing           1191
# 9          Information media and telecommunications           -776
# 10          Rental, hiring and real estate services           3587
# 11  Professional, scientific and technical services           2485
# 12              Administrative and support services           1237
# 13       Public administration and safety (private)            133
# 14                 Education and training (private)           -302
# 15      Health care and social assistance (private)           1142
# 16                     Arts and recreation services            218
# 17                                   Other services           -119
#
#     earnings_2018  earnings_2019
# 0           -2258           -998
# 1           21399          33746
# 2            4201           3346
# 3             481            670
# 4            3404           2504
# 5            3197           1099
# 6             516           -325
# 7              23            132
# 8             612           1371
# 9              -7          -2050
# 10           -212            157
# 11           1419           2238
# 12           -189            109
# 13            220             30
# 14            101            374
# 15           2155           1870
# 16            556            339
# 17           -482            862
